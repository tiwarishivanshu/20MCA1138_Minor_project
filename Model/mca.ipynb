# %%
def calculate_intrest(lst):
    if "sb" in lst:
        lst.append(float(lst[2]*lst[3])/100)
    else:
        lst.append(float(lst[1]*lst[4])/100)
    return lst

def calc(lst):
    if "fd" in lst:
        if lst[1]<1000000000 and lst[2]<50:
            print("first case for general fd below 1cr")
            if lst[3]>=1 and lst[3]<=7:
                lst.append(4.50)
            elif lst[3]>=14 and lst[3]<=29:
                lst.append(4.75)
            elif lst[3]>=30 and lst[3]<=45:
                lst.append(5.50)
            elif lst[3]>=45 and lst[3]<=60:
                lst.append(7)
            elif lst[3]>=61 and lst[3]<=184:
                lst.append(7.50)
            elif lst[3]>=185 and lst[3]<=365:
                lst.append(7)
        else:
            print("kindly enter the correct value")
        if lst[1]<1000000000 and lst[2]>50:#second case for seniors below 1cr
            print("first case for senior fd below 1cr")
            if lst[3]>=1 and lst[3]<=7:
                lst.append(5)
            elif lst[3]>=14 and lst[3]<=29:
                lst.append(5.25)
            elif lst[3]>=30 and lst[3]<=45:
                lst.append(6.00)
            elif lst[3]>=45 and lst[3]<=60:
                lst.append(7.50)
            elif lst[3]>=61 and lst[3]<=184:
                lst.append(8.00)
            elif lst[3]>=185 and lst[3]<=365:
                lst.append(8.50)
        else:
            print("kindly enter the correct value")
                
                
        if lst[1]>1000000000:
            print("first case above 1cr")
            if lst[3]>=1 and lst[3]<=7:
                lst.append(6.50)
            elif lst[3]>=14 and lst[3]<=29:
                lst.append(6.75)
            elif lst[3]>=30 and lst[3]<=45:
                lst.append(6.50)
            elif lst[3]>=45 and lst[3]<=60:
                lst.append(8.00)
            elif lst[3]>=61 and lst[3]<=184:
                lst.append(8.50)
            elif lst[3]>=185 and lst[3]<=365:
                lst.append(10.00)
        else:
            print("kindly enter the correct value")
    elif "rd" in lst:
        if lst[2]<45:#rd case general
            print("first case for general rd")
            if lst[3]==180:
                lst.append(7.50)
            elif lst[3]==270:
                lst.append(7.75)
            elif lst[3]==360:
                lst.append(8.00)
            elif lst[3]==450:
                lst.append(8.25)
            elif lst[3]==540:
                lst.append(8.50)
            elif lst[3]==630:
                lst.append(8.75)
            else:
                print("kindly enter the correct value")
                
        elif lst[2]>45:#rdcase seniors
            print("first case for senior rd")
            if lst[3]==180:
                lst.append(8)
            elif lst[3]==270:
                lst.append(8.25)
            elif lst[3]==360:
                lst.append(8.50)
            elif lst[3]==450:
                lst.append(8.75)
            elif lst[3]==540:
                lst.append(9.00)
            elif lst[3]==630:
                lst.append(9.25)
        else:
            print("kindly enter the correct value")
    elif "sb" in lst:
        if "normal" in lst:
            lst.append(4)
        elif "NRI" in lst:
            lst.append(6)
    else:
        print("enter the correct values")
    return lst
intrest
account_type=input("Enter your account Type: ")
intrest.append(account_type)
if "sb" in intrest:
    intrest.append(input("enter the account name"))
    amount=int(input("enter the amount: "))
    intrest.append(amount)
else:
    amount=int(input("enter the amount: "))
    intrest.append(amount)
    age=int(input("enter your age: "))
    intrest.append(age)
    days=int(input("enter the days for which you want to invest: "))
    intrest.append(days)
result=calc(intrest)
result
calculate_intrest(result)
print(f"the account type is: {result[0]} amount entered is {result[1]} age is {result[2]} for a days of {result[3]} so the intrest rate is {result[4]} and the intrest amount is {result[5]}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-498a5a1a1dcb> in <module>
#     101     return lst
#     102 intrest
# --> 103 account_type=input("Enter your account Type: ")
#     104 intrest.append(account_type)
#     105 if "sb" in intrest:
#
# ~/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
